# %%
# smallest between 4 numbers and quantity of smallest number
#a,b,c,d = 16,16,60,45
a = int(input("enter 1st number:"))
b = int(input("enter 2nd number:"))
c = int(input("enter 3rd number:"))
d = int(input("enter 4th number:"))
smallest=''
if a<b and a<c and a<d:
    smallest = a
elif b<a and b<c and b<d:
    smallest = b
elif c<a and c<b and c<d:
    smallest = c 
elif d<a and d<b and d<c:
    smallest = d

elif a == b:
    if b < c:
        if b < d:
            print(a, b, 'both are smallest')   
        elif b == d:
            print(a,b,d,'three of them are smallest')
        else:
            smallest = d 
    elif b == c:
        if c < d:
            print(a,b,c,'three of them are smallest')
        elif c == d:
            print('Every number is same')
        else:
            smallest = d  
    elif b > c:
        if c == d:
            print(c,d,'both are smallest')
        elif c < d:
            smallest = c
        else:
            smallest = d        

elif a == c:
    if c < b:
        if c < d:
            print(a, c, 'both are smallest')
        elif c == d:
            print(a,c,d,'three of them are smallest')
        else:
            smallest = d
    elif c == b:
        if c < d:
            print(a,b,c,'three of them are smallest')
        elif c == d:
            print('Every number is same')
        else:
            smallest = d 
    elif c > b:
        if b == d:
            print(b,d,'both are smallest')
        elif b < d:
            smallest = b
        else:
            smallest = d

elif a == d:
    if d < b:
        if d < c:
            print(a,d, ' both are smallest')
        elif d == c:
            print(a,c,d, 'three of them are smallest') 
        else:
            smallest = c
    elif d == b:
        if d < c:
            print(a,d,b,'three of them are smallest')  
        elif d == c:
            print("Every number is same")
        else:
            smallest = c
    elif d > b:
        if b == c:
            print(b,d, 'both are smallest')
        elif b < c:
            smallest = b
        else:
            smallest = c

elif b == c:
    if c < a:
        if c < d:
            print(b,c,'both are smallest')
        elif c == d:
            print(b,c,d,'three of them are smallest') 
        else:
            smallest = d
    elif c == a:
        if a == d:
            print("Every number is same") 
        elif a < d:
            print(a,b,c,'three of them are smallest')
        else:
            smallest = d
    elif c > a:
        if a == d:
            print(a,d, 'both are smallest')
        elif a < d:
            smallest = a
        else:
            smallest = d

elif b == d:
    if b < a:
        if b < c:
            print(b,d,'both are smallest')
        elif b == c:
            print(b,c,d, " three of them are smallest")
        else:
            smallest = c
    elif b == a:
        if a == c:
            print("Every number is same")
        elif a < c:
            print(a,b,d,'three of them are smallest')
        else:
            smallest = c
    elif b > a:
        if a == c:
            print(a,c, 'both are smallest')
        elif a < c:
            smallest = a
        else:
            smallest = c

elif c == d:
    if c < a:
        if c < b:
            print(c,d,'both are smallest')
        elif c == b:
            print(b,c,d, ' three of them are smallest')
        else:
            smallest = b
    elif c == a:
        if a == b:
            print("Every number is same")
        elif a < b:
            print(a,c,d, "three of them are smallest")
        else:
            smallest = b
    elif c > a:
        if a == b:
            print(a,b, 'both are smallest')
        elif a < b:
            smallest = a
        else:
            smallest = b
print(smallest)
# Out:
# 5 5 both are smallest

# %%
# By using Ternary Operator
a,b,c,d = 17,45,17,17
smallest = a if (a<=b and a<=c and a<=d) else (b if (b<=a and b<=c and b<=d) else (c if (c<=a and c<=b and c<=d)else d))
smallest
# Out:
# 17
